# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file_to_load = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
df = pd.read_csv(file_to_load)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Inspect all columns
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
cols_all = df.columns.tolist()
cols_all
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
#  'HasStudentDebt',
#  'HomeMortgageOwe',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobApplyWhen',
#  'JobPref',
#  'JobRelocateYesNo',
#  'JobRoleInterest',
#  'JobRoleInterestOther',
#  'JobWherePref',
#  'LanguageAtHome',
#  'MaritalStatus',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastChangeLog',
#  'PodcastCodeNewbie',
#  'PodcastCodingBlocks',
#  'PodcastDeveloperTea',
#  'PodcastDotNetRocks',
#  'PodcastHanselminutes',
#  'PodcastJSJabber',
#  'PodcastJsAir',
#  'PodcastNone',
#  'PodcastOther',
#  'PodcastProgrammingThrowDown',
#  'PodcastRubyRogues',
#  'PodcastSEDaily',
#  'PodcastShopTalk',
#  'PodcastTalkPython',
#  'PodcastWebAhead',
#  'ResourceBlogs',
#  'ResourceBooks',
#  'ResourceCodeWars',
#  'ResourceCodecademy',
#  'ResourceCoursera',
#  'ResourceDevTips',
#  'ResourceEdX',
#  'ResourceEggHead',
#  'ResourceFCC',
#  'ResourceGoogle',
#  'ResourceHackerRank',
#  'ResourceKhanAcademy',
#  'ResourceLynda',
#  'ResourceMDN',
#  'ResourceOdinProj',
#  'ResourceOther',
#  'ResourcePluralSight',
#  'ResourceReddit',
#  'ResourceSkillCrush',
#  'ResourceSoloLearn',
#  'ResourceStackOverflow',
#  'ResourceTreehouse',
#  'ResourceUdacity',
#  'ResourceUdemy',
#  'ResourceW3Schools',
#  'ResourceYouTube',
#  'SchoolDegree',
#  'SchoolMajor',
#  'StudentDebtOwe']

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
df_reduced = df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
cols_reduced = df_reduced.columns.tolist()
cols_reduced
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentStatus',
#  'Gender',
#  'HasChildren',
#  'HoursLearning',
#  'Income',
#  'JobRoleInterest',
#  'SchoolDegree',
#  'SchoolMajor']

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
df_reduced = df_reduced.replace([0.0],'No')
df_reduced = df_reduced.replace([1.0], 'Yes')
df_reduced.head(50)
# Out:
#      Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0   28.0               No            NaN                  NaN
# 1   22.0               No            NaN                  NaN
# 2   19.0               No            NaN                  NaN
# 3   26.0               No            NaN                  NaN
# 4   20.0               No            NaN                  NaN
# 5   34.0               No            NaN                  NaN
# 6   23.0               No            NaN                  NaN
# 7   35.0               No            NaN                  NaN
# 8   33.0               No            NaN                  NaN
# 9   33.0               No            NaN                  NaN
# 10  57.0               No            NaN                  NaN
# 11  23.0               No            NaN                  NaN
# 12  47.0               No            NaN                  NaN
# 13   NaN               No            NaN                  NaN
# 14  37.0               No            NaN                  NaN
# 15  31.0               No            NaN                  NaN
# 16  27.0               No            NaN                  NaN
# 17  29.0               No            NaN                  NaN
# 18  30.0               No            NaN                  NaN
# 19  30.0               No            NaN                  NaN
# 20  32.0               No            NaN                  NaN
# 21  25.0               No            NaN                  NaN
# 22  29.0               No            NaN                  NaN
# 23  44.0               No            NaN                  NaN
# 24  21.0               No            NaN                  NaN
# 25  21.0               No            NaN                  NaN
# 26  28.0               No            NaN                  NaN
# 27  28.0               No            NaN                  NaN
# 28  25.0               No            NaN                  NaN
# 29  35.0               No            NaN                  NaN
# 30  24.0               No            NaN                  NaN
# 31  23.0               No            NaN                  NaN
# 32  34.0               No            NaN                  NaN
# 33  18.0               No            NaN                  NaN
# 34  33.0               No            NaN                  NaN
# 35  28.0               No            NaN                  NaN
# 36  33.0               No            NaN                  NaN
# 37  26.0               No            NaN                  NaN
# 38  24.0               No            NaN                  NaN
# 39  39.0               No            NaN                  NaN
# 40  24.0               No            NaN                  NaN
# 41  34.0               No            NaN                  NaN
# 42  19.0               No            NaN                  NaN
# 43  28.0               No            NaN                  NaN
# 44  24.0               No            NaN                  NaN
# 45  41.0               No            NaN                  NaN
# 46  47.0               No            NaN                  NaN
# 47  22.0               No            NaN                  NaN
# 48  20.0               No            NaN                  NaN
# 49  20.0               No            NaN                  NaN
#
#    BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0                NaN                 NaN               NaN            NaN
# 1                NaN                 NaN               NaN            NaN
# 2                NaN                 NaN               NaN            NaN
# 3                NaN                 NaN               NaN            NaN
# 4                NaN                 NaN               NaN            NaN
# 5                NaN                 NaN               NaN            NaN
# 6                NaN                 NaN               NaN            NaN
# 7                NaN                 NaN               NaN            NaN
# 8                NaN                 NaN               NaN            NaN
# 9                NaN                 NaN               NaN            NaN
# 10               NaN                 NaN               NaN            NaN
# 11               NaN                 NaN               NaN            NaN
# 12               NaN                 NaN               NaN            NaN
# 13               NaN                 NaN               NaN            NaN
# 14               NaN                 NaN               NaN            Yes
# 15               NaN                 NaN               NaN            NaN
# 16               NaN                 NaN               NaN            NaN
# 17               NaN                 NaN               NaN            NaN
# 18               NaN                 NaN               NaN            NaN
# 19               NaN                 NaN               NaN            NaN
# 20               NaN                 NaN               NaN            Yes
# 21               NaN                 NaN               NaN            NaN
# 22               NaN                 NaN               NaN            NaN
# 23               NaN                 NaN               NaN            NaN
# 24               NaN                 NaN               NaN            NaN
# 25               NaN                 NaN               NaN            NaN
# 26               NaN                 NaN               NaN            NaN
# 27               NaN                 NaN               NaN              2
# 28               NaN                 NaN               NaN            NaN
# 29               NaN                 NaN               NaN            Yes
# 30               NaN                 NaN               NaN            NaN
# 31               NaN                 NaN               NaN            NaN
# 32               NaN                 NaN               NaN            NaN
# 33               NaN                 NaN               NaN            NaN
# 34               NaN                 NaN               NaN            NaN
# 35               NaN                 NaN               NaN            NaN
# 36               NaN                 NaN               NaN            NaN
# 37               NaN                 NaN               NaN            NaN
# 38               NaN                 NaN               NaN            NaN
# 39               NaN                 NaN               NaN            NaN
# 40               NaN                 NaN               NaN            NaN
# 41               NaN                 NaN               NaN            NaN
# 42               NaN                 NaN               NaN            NaN
# 43               NaN                 NaN               NaN            NaN
# 44               NaN                 NaN               NaN            NaN
# 45               NaN                 NaN               NaN              2
# 46               NaN                 NaN               NaN            Yes
# 47               NaN                 NaN               NaN            NaN
# 48               NaN                 NaN               NaN            NaN
# 49               NaN                 NaN               NaN            NaN
#
#                    CityPopulation CodeEventBootcamp               CountryLive  \
# 0   between 100,000 and 1 million               NaN  United States of America
# 1   between 100,000 and 1 million               NaN  United States of America
# 2             more than 1 million               NaN  United States of America
# 3             more than 1 million               NaN  United States of America
# 4   between 100,000 and 1 million               NaN  United States of America
# 5             more than 1 million               NaN  United States of America
# 6             more than 1 million               NaN                 Singapore
# 7   between 100,000 and 1 million               NaN            United Kingdom
# 8   between 100,000 and 1 million               NaN  United States of America
# 9             more than 1 million               NaN  United States of America
# 10              less than 100,000               NaN  United States of America
# 11            more than 1 million               NaN                Bangladesh
# 12            more than 1 million               NaN                    Canada
# 13  between 100,000 and 1 million               NaN  United States of America
# 14  between 100,000 and 1 million               NaN      Bosnia & Herzegovina
# 15            more than 1 million               NaN                    Russia
# 16            more than 1 million               NaN  United States of America
# 17              less than 100,000               NaN  United States of America
# 18            more than 1 million               NaN                    Canada
# 19              less than 100,000               NaN                   Croatia
# 20            more than 1 million               NaN  United States of America
# 21  between 100,000 and 1 million               NaN  United States of America
# 22  between 100,000 and 1 million               NaN  United States of America
# 23            more than 1 million               NaN  United States of America
# 24            more than 1 million               NaN                     India
# 25  between 100,000 and 1 million               NaN  United States of America
# 26              less than 100,000               NaN              South Africa
# 27            more than 1 million               NaN  United States of America
# 28  between 100,000 and 1 million               NaN  United States of America
# 29              less than 100,000               NaN            United Kingdom
# 30            more than 1 million               NaN  United States of America
# 31            more than 1 million               NaN                 Venezuela
# 32            more than 1 million               NaN  United States of America
# 33              less than 100,000               NaN  United States of America
# 34              less than 100,000               NaN  United States of America
# 35            more than 1 million               NaN                    Brazil
# 36  between 100,000 and 1 million               NaN  United States of America
# 37              less than 100,000               NaN  United States of America
# 38            more than 1 million               NaN              South Africa
# 39  between 100,000 and 1 million               NaN  United States of America
# 40  between 100,000 and 1 million               NaN                    Brazil
# 41              less than 100,000               NaN  United States of America
# 42            more than 1 million               NaN  United States of America
# 43            more than 1 million               NaN  United States of America
# 44            more than 1 million               NaN                    Canada
# 45              less than 100,000               NaN            United Kingdom
# 46            more than 1 million               NaN                     Italy
# 47  between 100,000 and 1 million               NaN                 Venezuela
# 48              less than 100,000               NaN                     India
# 49  between 100,000 and 1 million               NaN  United States of America
#
#                           EmploymentField  \
# 0       office and administrative support
# 1                       food and beverage
# 2                                 finance
# 3   arts, entertainment, sports, or media
# 4                               education
# 5                                 finance
# 6                    software development
# 7       office and administrative support
# 8                    software development
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                            health care
# 13                   software development
# 14                                  sales
# 15                   software development
# 16                   software development
# 17                              education
# 18                   software development
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22  arts, entertainment, sports, or media
# 23      office and administrative support
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                   software development
# 28                   software development
# 29                   software development
# 30                                    NaN
# 31                                    NaN
# 32                                    NaN
# 33                                    NaN
# 34                            health care
# 35      office and administrative support
# 36                                    NaN
# 37                                finance
# 38                   software development
# 39    law enforcement and fire and rescue
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                              education
# 44                                    NaN
# 45      office and administrative support
# 46                                  sales
# 47                                    NaN
# 48                                    NaN
# 49                   software development
#
#                         EmploymentStatus  Gender HasChildren HoursLearning  \
# 0                     Employed for wages    male          No            30
# 1                     Employed for wages    male         NaN            30
# 2                     Employed for wages    male         NaN            20
# 3                     Employed for wages  female         NaN            20
# 4                     Employed for wages  female         NaN            25
# 5               Self-employed freelancer    male         NaN             5
# 6                     Employed for wages    male         NaN             8
# 7                     Employed for wages    male          No           NaN
# 8                     Employed for wages    male         NaN             5
# 9                     Employed for wages    male         NaN            20
# 10          Self-employed business owner    male          No             8
# 11  Not working and not looking for work    male         NaN             5
# 12                    Employed for wages    male         NaN             5
# 13                    Employed for wages    male         NaN             5
# 14          Self-employed business owner    male         Yes             2
# 15                    Employed for wages  female         NaN            10
# 16                    Employed for wages  female         NaN             4
# 17                    Employed for wages    male         NaN             5
# 18              Self-employed freelancer    male         NaN             2
# 19      Not working but looking for work    male          No            20
# 20                    Employed for wages  female         Yes             5
# 21            Doing an unpaid internship  female         NaN           NaN
# 22                    Employed for wages  female          No            10
# 23                    Employed for wages  female          No            30
# 24      Not working but looking for work    male         NaN            25
# 25      Not working but looking for work    male         NaN            25
# 26              Self-employed freelancer    male          No           Yes
# 27                    Employed for wages    male         Yes            10
# 28                    Employed for wages    male         NaN            10
# 29                    Employed for wages    male         Yes             5
# 30            Doing an unpaid internship  female         NaN           NaN
# 31    A stay-at-home parent or homemaker    male         NaN            20
# 32            Doing an unpaid internship    male         NaN            20
# 33                    Employed for wages  female         NaN            10
# 34                    Employed for wages  female         NaN            15
# 35                    Employed for wages    male         NaN             7
# 36              Self-employed freelancer    male          No            20
# 37                    Employed for wages    male         NaN             3
# 38                    Employed for wages    male         NaN            10
# 39                    Employed for wages    male         NaN            25
# 40      Not working but looking for work    male         NaN            10
# 41  Not working and not looking for work    male         NaN            20
# 42                                   NaN    male         NaN             2
# 43                    Employed for wages    male         NaN            15
# 44      Not working but looking for work    male         NaN           NaN
# 45                    Employed for wages    male         Yes            10
# 46              Self-employed freelancer    male         Yes            15
# 47      Not working but looking for work    male         NaN            10
# 48            Doing an unpaid internship  female         NaN            10
# 49                    Employed for wages    male         NaN            20
#
#       Income                   JobRoleInterest  \
# 0    32000.0                               NaN
# 1    15000.0           Front-End Web Developer
# 2    48000.0                               NaN
# 3    43000.0           Front-End Web Developer
# 4     6000.0          Full-Stack Web Developer
# 5    40000.0                               NaN
# 6    32000.0                               NaN
# 7    40000.0                               NaN
# 8    80000.0                               NaN
# 9    80000.0                               NaN
# 10   20000.0                               NaN
# 11       NaN                               NaN
# 12   90000.0                               NaN
# 13       NaN                               NaN
# 14       NaN                               NaN
# 15       NaN                               NaN
# 16   80000.0                               NaN
# 17   17000.0                               NaN
# 18   16000.0                               NaN
# 19       NaN          Full-Stack Web Developer
# 20  200000.0          Full-Stack Web Developer
# 21       NaN                               NaN
# 22  100000.0                               NaN
# 23   41000.0                               NaN
# 24       NaN                               NaN
# 25       NaN          Full-Stack Web Developer
# 26   12000.0                               NaN
# 27   60000.0                               NaN
# 28   75000.0          Full-Stack Web Developer
# 29   35000.0                               NaN
# 30       NaN                               NaN
# 31       NaN          Full-Stack Web Developer
# 32       NaN          Full-Stack Web Developer
# 33    6000.0           Front-End Web Developer
# 34   40000.0                               NaN
# 35    6500.0                               NaN
# 36   60000.0          Full-Stack Web Developer
# 37   29000.0                               NaN
# 38   10000.0                               NaN
# 39   53000.0          Full-Stack Web Developer
# 40       NaN          Full-Stack Web Developer
# 41       NaN                               NaN
# 42       NaN    Data Scientist / Data Engineer
# 43   52000.0          Full-Stack Web Developer
# 44       NaN                               NaN
# 45   17000.0                               NaN
# 46   20000.0                               NaN
# 47       NaN                  Mobile Developer
# 48       NaN          Full-Stack Web Developer
# 49   24000.0          Full-Stack Web Developer
#
#                                 SchoolDegree              SchoolMajor
# 0             some college credit, no degree                      NaN
# 1             some college credit, no degree                      NaN
# 2    high school diploma or equivalent (GED)                      NaN
# 3                          bachelor's degree  Cinematography And Film
# 4             some college credit, no degree                      NaN
# 5                          bachelor's degree                  English
# 6                          bachelor's degree         Computer Science
# 7         master's degree (non-professional)                Education
# 8                          bachelor's degree  Business Administration
# 9         master's degree (non-professional)  Business Administration
# 10                         bachelor's degree         Computer Science
# 11            some college credit, no degree                      NaN
# 12                         bachelor's degree   Mechanical Engineering
# 13                         bachelor's degree  Business Administration
# 14            some college credit, no degree                      NaN
# 15   professional degree (MBA, MD, JD, etc.)                     Math
# 16                         bachelor's degree                Economics
# 17                         bachelor's degree                    Music
# 18                         bachelor's degree                    Music
# 19            some college credit, no degree                      NaN
# 20        master's degree (non-professional)                  Geology
# 21                         bachelor's degree         Computer Science
# 22                         bachelor's degree         Computer Science
# 23                         bachelor's degree        Political Science
# 24                         bachelor's degree         Computer Science
# 25            some college credit, no degree                      NaN
# 26   high school diploma or equivalent (GED)                      NaN
# 27  trade, technical, or vocational training                      NaN
# 28                         bachelor's degree        Political Science
# 29        master's degree (non-professional)                  Physics
# 30            some college credit, no degree                      NaN
# 31            some college credit, no degree                      NaN
# 32                         bachelor's degree   Information Technology
# 33   high school diploma or equivalent (GED)                      NaN
# 34                         bachelor's degree                  English
# 35   high school diploma or equivalent (GED)                      NaN
# 36   high school diploma or equivalent (GED)                      NaN
# 37            some college credit, no degree                      NaN
# 38                         bachelor's degree         Computer Science
# 39                        associate's degree   Information Technology
# 40   high school diploma or equivalent (GED)                      NaN
# 41   high school diploma or equivalent (GED)                      NaN
# 42            some college credit, no degree                      NaN
# 43                         bachelor's degree           Communications
# 44   high school diploma or equivalent (GED)                      NaN
# 45        master's degree (non-professional)                  English
# 46   high school diploma or equivalent (GED)                      NaN
# 47   high school diploma or equivalent (GED)                      NaN
# 48   high school diploma or equivalent (GED)                      NaN
# 49   high school diploma or equivalent (GED)                      NaN

# %%
# Calculate total number of respondents in survey
nr = len(df_reduced.index)
nr
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
df_attended = df_reduced.loc[df_reduced['AttendedBootcamp']=='Yes']
df_attended.head(100)
# Out:
#        Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93    32.0              Yes            Yes                   No
# 97    26.0              Yes            Yes                  Yes
# 130   41.0              Yes            Yes                  Yes
# 159   26.0              Yes            Yes                   No
# 188   24.0              Yes             No                  NaN
# ...    ...              ...            ...                  ...
# 2324  28.0              Yes             No                  NaN
# 2344  33.0              Yes            Yes                   No
# 2345  27.0              Yes            Yes                   No
# 2361  26.0              Yes            Yes                  Yes
# 2363  27.0              Yes             No                  NaN
#
#      BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                  No                 NaN                No            NaN
# 97                  No             45000.0                No            NaN
# 130                Yes             75000.0               Yes              3
# 159                 No                 NaN                No            NaN
# 188                Yes                 NaN                No            NaN
# ...                ...                 ...               ...            ...
# 2324                No                 NaN               Yes            NaN
# 2344               Yes                 NaN                No            NaN
# 2345                No                 NaN               Yes            NaN
# 2361               Yes             70000.0               Yes            Yes
# 2363               Yes                 NaN               Yes            NaN
#
#                      CityPopulation CodeEventBootcamp  \
# 93    between 100,000 and 1 million               NaN
# 97              more than 1 million               NaN
# 130               less than 100,000               NaN
# 159   between 100,000 and 1 million               NaN
# 188   between 100,000 and 1 million               NaN
# ...                             ...               ...
# 2324            more than 1 million               NaN
# 2344  between 100,000 and 1 million               NaN
# 2345            more than 1 million               NaN
# 2361  between 100,000 and 1 million               NaN
# 2363  between 100,000 and 1 million               NaN
#
#                    CountryLive                        EmploymentField  \
# 93    United States of America  arts, entertainment, sports, or media
# 97    United States of America                   software development
# 130   United States of America                   software development
# 159   United States of America                                    NaN
# 188                     Canada                                    NaN
# ...                        ...                                    ...
# 2324  United States of America                                  sales
# 2344  United States of America                                    NaN
# 2345  United States of America                                    NaN
# 2361  United States of America            software development and IT
# 2363               New Zealand                      food and beverage
#
#                           EmploymentStatus  Gender HasChildren HoursLearning  \
# 93            Self-employed business owner    male         NaN            20
# 97                      Employed for wages    male          No            10
# 130                     Employed for wages    male         Yes            30
# 159   Not working and not looking for work  female         NaN            30
# 188       Not working but looking for work  female         NaN            60
# ...                                    ...     ...         ...           ...
# 2324                    Employed for wages    male          No            30
# 2344      Not working but looking for work    male         NaN            20
# 2345      Not working but looking for work  female         NaN            20
# 2361                    Employed for wages    male         Yes             5
# 2363                    Employed for wages  female         NaN            15
#
#        Income            JobRoleInterest  \
# 93    67000.0                        NaN
# 97    40000.0                        NaN
# 130   75000.0                        NaN
# 159       NaN   Full-Stack Web Developer
# 188       NaN                        NaN
# ...       ...                        ...
# 2324  16000.0   Full-Stack Web Developer
# 2344      NaN                        NaN
# 2345      NaN    Front-End Web Developer
# 2361  40000.0                        NaN
# 2363  15000.0   Full-Stack Web Developer
#
#                                  SchoolDegree       SchoolMajor
# 93                          bachelor's degree           Biology
# 97         master's degree (non-professional)             Music
# 130            some college credit, no degree               NaN
# 159            some college credit, no degree               NaN
# 188            some college credit, no degree               NaN
# ...                                       ...               ...
# 2324                       associate's degree  Computer Science
# 2344                        bachelor's degree           Nursing
# 2345                        bachelor's degree      Liberal Arts
# 2361  professional degree (MBA, MD, JD, etc.)      Liberal Arts
# 2363       master's degree (non-professional)        Psychology
#
# [100 rows x 20 columns]

# %%
# Calculate average age of attendees
mean_attendee_age = df_attended['Age'].mean()
mean_attendee_age
# Out:
# 31.066014669926652

# %%
# Calculate how many people attended a bootcamp
number_attended_bootcamp = len(df_attended.index)
number_attended_bootcamp
# Out:
# 953

# %%
# Calculate how many attendees hold degrees
#hold_degree = df_attended["SchoolDegree"].count()
#hold_degree
hold_degree = number_attended_bootcamp - df_attended['SchoolMajor'].isnull().sum()
hold_degree
# Out:
# 622

# %%
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification

# %%
# Calculate percentage of respondents who attended a bootcamp

# %%
# Calculate percentage of respondents belonging to each gender

# %%
# Calculate percentage of attendees with a school degree

# %%
# Calculate average post-bootcamp salary
# Out:
# 953

# %%
# Create a new table consolodating above calculations

# %%
# Improve formatting before outputting spreadsheet

# %%
# Export to Excel
